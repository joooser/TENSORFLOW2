# %% [markdown]
# <a href="https://colab.research.google.com/github/joooser/TENSORFLOW2/blob/main/entrenamiento_modelo_carro_moto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importamos librerías

# %%
import os
import pandas as pd
import json
import pickle
import zipfile
import shutil

# Instalamos los paquetes necesarios para que funcione desde la Colab
# !pip install avro-python3
# !pip install 
# !pip install tf_slim==1.1.0
# !pip install tf-models-official==2.8.0
# !pip install lvis
# !pip install tensorflow_io==0.23.1
# !pip install keras==2.8.0
# !pip install opencv-python-headless==4.5.2.52
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: avro-python3 in /usr/local/lib/python3.7/dist-packages (1.10.2)
# ERROR: You must give at least one requirement to install (see "pip help install")
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tf_slim==1.1.0 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf_slim==1.1.0) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tf-models-official==2.8.0
#   Downloading tf_models_official-2.8.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 33.8 MB/s
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.3.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.7.3)
# Requirement already satisfied: tensorflow-text~=2.8.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (2.8.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (3.2.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (2.0.4)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (8.0.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (0.17.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.21.6)
# Requirement already satisfied: tensorflow~=2.8.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: tf-slim>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.1.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (4.5.2.52)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (0.5.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (0.29.30)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (0.12.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.2.2)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 65.6 MB/s
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (5.4.8)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (4.0.1)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.12.11)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.5.12)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (0.1.96)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (4.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (1.15.0)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (2.1.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (7.1.2)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tf-models-official==2.8.0) (0.7.3)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (1.31.6)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (0.0.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (1.35.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (0.17.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (2.23.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (1.56.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (2022.1)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (21.3)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (3.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (4.2.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (4.64.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (6.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (2022.6.15)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (3.0.4)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (14.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.6.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.47.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (2.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (2.8.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (4.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (3.3.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (0.23.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (0.2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official==2.8.0) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.8.0->tf-models-official==2.8.0) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (3.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (3.8.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (3.2.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official==2.8.0) (0.1.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->tf-models-official==2.8.0) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->tf-models-official==2.8.0) (0.11.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.8.0) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official==2.8.0) (0.8.10)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official==2.8.0) (2022.6.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official==2.8.0) (2.5.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official==2.8.0) (0.4.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official==2.8.0) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official==2.8.0) (2.7.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0) (1.9.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0) (0.16.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0) (2.3)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0) (21.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0) (5.8.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0) (0.3.5.1)
# Installing collected packages: pyyaml, tf-models-official
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: tf-models-official
#     Found existing installation: tf-models-official 2.7.0
#     Uninstalling tf-models-official-2.7.0:
#       Successfully uninstalled tf-models-official-2.7.0
# Successfully installed pyyaml-5.4.1 tf-models-official-2.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lvis in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (1.4.4)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (2.8.2)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis) (4.6.0.66)
# Requirement already satisfied: pyparsing>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (3.0.9)
# Requirement already satisfied: Cython>=0.29.12 in /usr/local/lib/python3.7/dist-packages (from lvis) (0.29.30)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from lvis) (3.2.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.7/dist-packages (from lvis) (1.21.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.1.0->lvis) (4.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_io==0.23.1 in /usr/local/lib/python3.7/dist-packages (0.23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow_io==0.23.1) (0.23.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras==2.8.0 in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python-headless==4.5.2.52 in /usr/local/lib/python3.7/dist-packages (4.5.2.52)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.5.2.52) (1.21.6)

# %% [markdown]
# ## Creamos nuestro archivo Label Map

# %%
labels = [{'name':'carro', 'id': 1}, {'name': 'motos', 'id': 2}]
with open("label_map.pbtxt", "w") as f:
  for label in labels:
    f.write('item { \n')
    f.write('\tname:\'{}\'\n'.format(label['name']))
    f.write('\tid:{}\n'.format(label['id']))
    f.write('}\n')

# %% [markdown]
# ## Instalamos la librería de Object Detection en Google Colab

# %%
import os
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git
# %cd /content/models/
#!git checkout 58d19c67e1d30d905dd5c6e5092348658fed80af
# !apt-get update && apt-get install -y -qq protobuf-compiler python-pil python-lxml python-tk
# !pip install -q Cython contextlib2 pillow lxml matplotlib
# !pip install -q pycocotools
# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'
# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# fatal: destination path 'models' already exists and is not an empty directory.
# /content/models
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 252 kB in 2s (138 kB/s)
# Reading package lists... Done
# /content/models/research

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %% [markdown]
# ## Clonamos el modelo SSD Mobilenet v2
# Si deseas puedes clonar cualquiera de los modelos pre entrenados

# %%
# Descargamos los modelos pre-enterenados en este caso SSD + MobileNetV2
# !wget --no-check-certificate http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz \
    -O /content/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# --2022-07-24 19:22:47--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.217.194.128, 2404:6800:4003:c00::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.217.194.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘/content/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# /content/ssd_mobile 100%[===================>]  19.56M  52.8MB/s    in 0.4s
#
# 2022-07-24 19:22:48 (52.8 MB/s) - ‘/content/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]

# %% [markdown]
# #### Descromprimimos el modelo pre-entrenado

# %%
# !tar -zxvf /content/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
output_path = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
output_path = os.path.join(os.getcwd(), output_path)
print("La carpeta se almaceno en {}".format(output_path))
# Out:
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index
# La carpeta se almaceno en /content/models/research/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8

# %% [markdown]
# #### Definimos la ruta de nuestro modelo

# %%
path_training = '/content/ssd_mobilenet'
os.mkdir(path_training)

# %% [markdown]
# ## Definimos la ruta del archivo original pipeline.config y en dónde vamos a almacenar nuestro pipeline.config

# %%
source_config = "{}/pipeline.config".format(output_path)
target_config = "{}/pipeline.config".format(path_training)
shutil.copyfile(source_config, target_config)
# Out:
# '/content/ssd_mobilenet/pipeline.config'

# %% [markdown]
# ## Configuramos el archivo pipeline.config
# Inicialmente importamos librerías

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
# Obtenemos la configuración del archivo pipeline
config = config_util.get_configs_from_pipeline_file(target_config)

# %%
# Visualizamos la configuración base
config
# Out:
# {'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
# Creamos una variable proto_str para poder modificar las variables del archivo pbtxt
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(target_config, "r") as f:
  proto_str = f.read()
  text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config
# Out:
# model {
#   ssd {
#     num_classes: 90
#     image_resizer {
#       fixed_shape_resizer {
#         height: 320
#         width: 320
#       }
#     }
#     feature_extractor {
#       type: "ssd_mobilenet_v2_fpn_keras"
#       depth_multiplier: 1.0
#       min_depth: 16
#       conv_hyperparams {
#         regularizer {
#           l2_regularizer {
#             weight: 3.9999998989515007e-05
#           }
#         }
#         initializer {
#           random_normal_initializer {
#             mean: 0.0
#             stddev: 0.009999999776482582
#           }
#         }
#         activation: RELU_6
#         batch_norm {
#           decay: 0.996999979019165
#           scale: true
#           epsilon: 0.0010000000474974513
#         }
#       }
#       use_depthwise: true
#       override_base_feature_extractor_hyperparams: true
#       fpn {
#         min_level: 3
#         max_level: 7
#         additional_layer_depth: 128
#       }
#     }
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         conv_hyperparams {
#           regularizer {
#             l2_regularizer {
#               weight: 3.9999998989515007e-05
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               mean: 0.0
#               stddev: 0.009999999776482582
#             }
#           }
#           activation: RELU_6
#           batch_norm {
#             decay: 0.996999979019165
#             scale: true
#             epsilon: 0.0010000000474974513
#           }
#         }
#         depth: 128
#         num_layers_before_predictor: 4
#         kernel_size: 3
#         class_prediction_bias_init: -4.599999904632568
#         share_prediction_tower: true
#         use_depthwise: true
#       }
#     }
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         scales_per_octave: 2
#       }
#     }
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 9.99999993922529e-09
#         iou_threshold: 0.6000000238418579
#         max_detections_per_class: 100
#         max_total_detections: 100
#         use_static_shapes: false
#       }
#       score_converter: SIGMOID
#     }
#     normalize_loss_by_num_matches: true
#     loss {
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_loss {
#         weighted_sigmoid_focal {
#           gamma: 2.0
#           alpha: 0.25
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     encode_background_as_zeros: true
#     normalize_loc_loss_by_codesize: true
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#   }
# }
# train_config {
#   batch_size: 128
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     random_crop_image {
#       min_object_covered: 0.0
#       min_aspect_ratio: 0.75
#       max_aspect_ratio: 3.0
#       min_area: 0.75
#       max_area: 1.0
#       overlap_thresh: 0.0
#     }
#   }
#   sync_replicas: true
#   optimizer {
#     momentum_optimizer {
#       learning_rate {
#         cosine_decay_learning_rate {
#           learning_rate_base: 0.07999999821186066
#           total_steps: 50000
#           warmup_learning_rate: 0.026666000485420227
#           warmup_steps: 1000
#         }
#       }
#       momentum_optimizer_value: 0.8999999761581421
#     }
#     use_moving_average: false
#   }
#   fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#   num_steps: 50000
#   startup_delay_steps: 0.0
#   replicas_to_aggregate: 8
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
#   fine_tune_checkpoint_type: "classification"
#   fine_tune_checkpoint_version: V2
# }
# train_input_reader {
#   label_map_path: "PATH_TO_BE_CONFIGURED"
#   tf_record_input_reader {
#     input_path: "PATH_TO_BE_CONFIGURED"
#   }
# }
# eval_config {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
# eval_input_reader {
#   label_map_path: "PATH_TO_BE_CONFIGURED"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "PATH_TO_BE_CONFIGURED"
#   }
# }

# %%
# Definimos las rutas en donde se encuentra los TFRecords y el label map para agregarlos al archivo de configuración del pipeline.config
label_map_pbtxt_fname = "/content/label_map.pbtxt"
train_record_fname = "/content/train.record"
test_record_fname = "/content/test.record"

# %%
# Cantidad de clases del modelo
pipeline_config.model.ssd.num_classes = 2

# El tamaño del batch size, entre más grande mas costo computacional va a necesitar en el proceso de entrenamiento, pero a su vez entrenara más rapido.
pipeline_config.train_config.batch_size = 4

# Donde almacenaremos los resultados del entrenamiento
pipeline_config.train_config.fine_tune_checkpoint ="{}/checkpoint/ckpt-0".format(output_path)

# Qué tipo de deteción aplicaremos (Object detection)
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"

# Dirección del label map
pipeline_config.train_input_reader.label_map_path = label_map_pbtxt_fname

# Dirección del train TFRecord
pipeline_config.train_input_reader.tf_record_input_reader.input_path[0] = train_record_fname

# Dirección del label map
pipeline_config.eval_input_reader[0].label_map_path = label_map_pbtxt_fname

# Dirección del test TFRecord
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[0] = test_record_fname

# %%
# Visualizamos nuestro pipeline_config final.
pipeline_config
# Out:
# model {
#   ssd {
#     num_classes: 2
#     image_resizer {
#       fixed_shape_resizer {
#         height: 320
#         width: 320
#       }
#     }
#     feature_extractor {
#       type: "ssd_mobilenet_v2_fpn_keras"
#       depth_multiplier: 1.0
#       min_depth: 16
#       conv_hyperparams {
#         regularizer {
#           l2_regularizer {
#             weight: 3.9999998989515007e-05
#           }
#         }
#         initializer {
#           random_normal_initializer {
#             mean: 0.0
#             stddev: 0.009999999776482582
#           }
#         }
#         activation: RELU_6
#         batch_norm {
#           decay: 0.996999979019165
#           scale: true
#           epsilon: 0.0010000000474974513
#         }
#       }
#       use_depthwise: true
#       override_base_feature_extractor_hyperparams: true
#       fpn {
#         min_level: 3
#         max_level: 7
#         additional_layer_depth: 128
#       }
#     }
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         conv_hyperparams {
#           regularizer {
#             l2_regularizer {
#               weight: 3.9999998989515007e-05
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               mean: 0.0
#               stddev: 0.009999999776482582
#             }
#           }
#           activation: RELU_6
#           batch_norm {
#             decay: 0.996999979019165
#             scale: true
#             epsilon: 0.0010000000474974513
#           }
#         }
#         depth: 128
#         num_layers_before_predictor: 4
#         kernel_size: 3
#         class_prediction_bias_init: -4.599999904632568
#         share_prediction_tower: true
#         use_depthwise: true
#       }
#     }
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         scales_per_octave: 2
#       }
#     }
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 9.99999993922529e-09
#         iou_threshold: 0.6000000238418579
#         max_detections_per_class: 100
#         max_total_detections: 100
#         use_static_shapes: false
#       }
#       score_converter: SIGMOID
#     }
#     normalize_loss_by_num_matches: true
#     loss {
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_loss {
#         weighted_sigmoid_focal {
#           gamma: 2.0
#           alpha: 0.25
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     encode_background_as_zeros: true
#     normalize_loc_loss_by_codesize: true
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#   }
# }
# train_config {
#   batch_size: 4
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     random_crop_image {
#       min_object_covered: 0.0
#       min_aspect_ratio: 0.75
#       max_aspect_ratio: 3.0
#       min_area: 0.75
#       max_area: 1.0
#       overlap_thresh: 0.0
#     }
#   }
#   sync_replicas: true
#   optimizer {
#     momentum_optimizer {
#       learning_rate {
#         cosine_decay_learning_rate {
#           learning_rate_base: 0.07999999821186066
#           total_steps: 50000
#           warmup_learning_rate: 0.026666000485420227
#           warmup_steps: 1000
#         }
#       }
#       momentum_optimizer_value: 0.8999999761581421
#     }
#     use_moving_average: false
#   }
#   fine_tune_checkpoint: "/content/models/research/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0"
#   num_steps: 50000
#   startup_delay_steps: 0.0
#   replicas_to_aggregate: 8
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
#   fine_tune_checkpoint_type: "detection"
#   fine_tune_checkpoint_version: V2
# }
# train_input_reader {
#   label_map_path: "/content/label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/train.record"
#   }
# }
# eval_config {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
# eval_input_reader {
#   label_map_path: "/content/label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/content/test.record"
#   }
# }

# %%
# Almacenamos nuestro archivo final
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(target_config, "wb") as f:
  f.write(config_text)

# %% [markdown]
# ## Entrenamiento de modelo de object detection

# %%
num_steps = 5000
model_dir = "/content/ssd_mobilenet"

# Utilizamos directamente la libreria de object detection para ejecutar el script model_main_tf2
# Los argumentos principales son el archivo de configuración, la ubicación del modelo y la cantidad de steps que ejecutará.
# !python /content/models/research/object_detection/model_main_tf2.py \
--pipeline_config_path={target_config} \
--model_dir={model_dir} \
--num_train_steps={num_steps}
# Out:
# 2022-07-24 19:23:19.351813: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0724 19:23:19.391242 139858778781568 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 5000
# I0724 19:23:19.394867 139858778781568 config_util.py:552] Maybe overwriting train_steps: 5000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0724 19:23:19.395036 139858778781568 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0724 19:23:19.542170 139858778781568 deprecation.py:343] From /content/models/research/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/train.record']
# I0724 19:23:19.554348 139858778781568 dataset_builder.py:162] Reading unweighted datasets: ['/content/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/train.record']
# I0724 19:23:19.554569 139858778781568 dataset_builder.py:79] Reading record datasets for input file: ['/content/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0724 19:23:19.554652 139858778781568 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0724 19:23:19.554708 139858778781568 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0724 19:23:19.562601 139858778781568 deprecation.py:343] From /content/models/research/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0724 19:23:19.597293 139858778781568 deprecation.py:343] From /content/models/research/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0724 19:23:26.957011 139858778781568 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0724 19:23:29.806966 139858778781568 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0724 19:23:31.203604 139858778781568 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.068900 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.070107 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.072066 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.072902 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.074788 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.075617 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.077509 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.078315 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.080220 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0724 19:24:05.081039 139858778781568 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0724 19:24:05.670081 139853835998976 deprecation.py:547] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.406s
# I0724 19:24:46.128209 139858778781568 model_lib_v2.py:707] Step 100 per-step time 0.406s
# INFO:tensorflow:{'Loss/classification_loss': 0.45805272,
#  'Loss/localization_loss': 0.38250372,
#  'Loss/regularization_loss': 0.15430646,
#  'Loss/total_loss': 0.9948629,
#  'learning_rate': 0.0319994}
# I0724 19:24:46.128547 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.45805272,
#  'Loss/localization_loss': 0.38250372,
#  'Loss/regularization_loss': 0.15430646,
#  'Loss/total_loss': 0.9948629,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.097s
# I0724 19:24:55.584229 139858778781568 model_lib_v2.py:707] Step 200 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.2694543,
#  'Loss/localization_loss': 0.23493147,
#  'Loss/regularization_loss': 0.15458646,
#  'Loss/total_loss': 0.65897226,
#  'learning_rate': 0.0373328}
# I0724 19:24:55.584595 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.2694543,
#  'Loss/localization_loss': 0.23493147,
#  'Loss/regularization_loss': 0.15458646,
#  'Loss/total_loss': 0.65897226,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.097s
# I0724 19:25:05.257882 139858778781568 model_lib_v2.py:707] Step 300 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.18302202,
#  'Loss/localization_loss': 0.1804744,
#  'Loss/regularization_loss': 0.15477207,
#  'Loss/total_loss': 0.51826847,
#  'learning_rate': 0.0426662}
# I0724 19:25:05.258182 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.18302202,
#  'Loss/localization_loss': 0.1804744,
#  'Loss/regularization_loss': 0.15477207,
#  'Loss/total_loss': 0.51826847,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.095s
# I0724 19:25:14.734397 139858778781568 model_lib_v2.py:707] Step 400 per-step time 0.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.24974723,
#  'Loss/localization_loss': 0.17347468,
#  'Loss/regularization_loss': 0.15485011,
#  'Loss/total_loss': 0.578072,
#  'learning_rate': 0.047999598}
# I0724 19:25:14.734697 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.24974723,
#  'Loss/localization_loss': 0.17347468,
#  'Loss/regularization_loss': 0.15485011,
#  'Loss/total_loss': 0.578072,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.094s
# I0724 19:25:24.097596 139858778781568 model_lib_v2.py:707] Step 500 per-step time 0.094s
# INFO:tensorflow:{'Loss/classification_loss': 0.27375826,
#  'Loss/localization_loss': 0.27972817,
#  'Loss/regularization_loss': 0.15486705,
#  'Loss/total_loss': 0.7083535,
#  'learning_rate': 0.053333}
# I0724 19:25:24.097893 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.27375826,
#  'Loss/localization_loss': 0.27972817,
#  'Loss/regularization_loss': 0.15486705,
#  'Loss/total_loss': 0.7083535,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.097s
# I0724 19:25:33.805895 139858778781568 model_lib_v2.py:707] Step 600 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.16557786,
#  'Loss/localization_loss': 0.11639667,
#  'Loss/regularization_loss': 0.1548555,
#  'Loss/total_loss': 0.43683004,
#  'learning_rate': 0.0586664}
# I0724 19:25:33.806204 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.16557786,
#  'Loss/localization_loss': 0.11639667,
#  'Loss/regularization_loss': 0.1548555,
#  'Loss/total_loss': 0.43683004,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.095s
# I0724 19:25:43.328608 139858778781568 model_lib_v2.py:707] Step 700 per-step time 0.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.15470357,
#  'Loss/localization_loss': 0.120397024,
#  'Loss/regularization_loss': 0.15459308,
#  'Loss/total_loss': 0.42969367,
#  'learning_rate': 0.0639998}
# I0724 19:25:43.328890 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.15470357,
#  'Loss/localization_loss': 0.120397024,
#  'Loss/regularization_loss': 0.15459308,
#  'Loss/total_loss': 0.42969367,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.095s
# I0724 19:25:52.870941 139858778781568 model_lib_v2.py:707] Step 800 per-step time 0.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.13972485,
#  'Loss/localization_loss': 0.11943759,
#  'Loss/regularization_loss': 0.15432248,
#  'Loss/total_loss': 0.4134849,
#  'learning_rate': 0.069333196}
# I0724 19:25:52.871223 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.13972485,
#  'Loss/localization_loss': 0.11943759,
#  'Loss/regularization_loss': 0.15432248,
#  'Loss/total_loss': 0.4134849,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.095s
# I0724 19:26:02.411558 139858778781568 model_lib_v2.py:707] Step 900 per-step time 0.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.16758469,
#  'Loss/localization_loss': 0.15470107,
#  'Loss/regularization_loss': 0.1540194,
#  'Loss/total_loss': 0.4763052,
#  'learning_rate': 0.074666604}
# I0724 19:26:02.411896 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.16758469,
#  'Loss/localization_loss': 0.15470107,
#  'Loss/regularization_loss': 0.1540194,
#  'Loss/total_loss': 0.4763052,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.097s
# I0724 19:26:12.109690 139858778781568 model_lib_v2.py:707] Step 1000 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.110024594,
#  'Loss/localization_loss': 0.113636196,
#  'Loss/regularization_loss': 0.15361269,
#  'Loss/total_loss': 0.3772735,
#  'learning_rate': 0.08}
# I0724 19:26:12.109976 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.110024594,
#  'Loss/localization_loss': 0.113636196,
#  'Loss/regularization_loss': 0.15361269,
#  'Loss/total_loss': 0.3772735,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.104s
# I0724 19:26:22.468358 139858778781568 model_lib_v2.py:707] Step 1100 per-step time 0.104s
# INFO:tensorflow:{'Loss/classification_loss': 0.16427505,
#  'Loss/localization_loss': 0.06109185,
#  'Loss/regularization_loss': 0.15333486,
#  'Loss/total_loss': 0.37870175,
#  'learning_rate': 0.07999918}
# I0724 19:26:22.468661 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.16427505,
#  'Loss/localization_loss': 0.06109185,
#  'Loss/regularization_loss': 0.15333486,
#  'Loss/total_loss': 0.37870175,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.096s
# I0724 19:26:32.033859 139858778781568 model_lib_v2.py:707] Step 1200 per-step time 0.096s
# INFO:tensorflow:{'Loss/classification_loss': 0.12283,
#  'Loss/localization_loss': 0.07441463,
#  'Loss/regularization_loss': 0.15321176,
#  'Loss/total_loss': 0.35045642,
#  'learning_rate': 0.079996705}
# I0724 19:26:32.034166 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.12283,
#  'Loss/localization_loss': 0.07441463,
#  'Loss/regularization_loss': 0.15321176,
#  'Loss/total_loss': 0.35045642,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.094s
# I0724 19:26:41.478483 139858778781568 model_lib_v2.py:707] Step 1300 per-step time 0.094s
# INFO:tensorflow:{'Loss/classification_loss': 0.109419264,
#  'Loss/localization_loss': 0.05373688,
#  'Loss/regularization_loss': 0.15264957,
#  'Loss/total_loss': 0.31580573,
#  'learning_rate': 0.0799926}
# I0724 19:26:41.478790 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.109419264,
#  'Loss/localization_loss': 0.05373688,
#  'Loss/regularization_loss': 0.15264957,
#  'Loss/total_loss': 0.31580573,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.096s
# I0724 19:26:51.056339 139858778781568 model_lib_v2.py:707] Step 1400 per-step time 0.096s
# INFO:tensorflow:{'Loss/classification_loss': 0.08370921,
#  'Loss/localization_loss': 0.04897886,
#  'Loss/regularization_loss': 0.15214139,
#  'Loss/total_loss': 0.28482947,
#  'learning_rate': 0.07998685}
# I0724 19:26:51.056644 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.08370921,
#  'Loss/localization_loss': 0.04897886,
#  'Loss/regularization_loss': 0.15214139,
#  'Loss/total_loss': 0.28482947,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.095s
# I0724 19:27:00.552507 139858778781568 model_lib_v2.py:707] Step 1500 per-step time 0.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.10839872,
#  'Loss/localization_loss': 0.054810014,
#  'Loss/regularization_loss': 0.15158631,
#  'Loss/total_loss': 0.31479505,
#  'learning_rate': 0.07997945}
# I0724 19:27:00.552819 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.10839872,
#  'Loss/localization_loss': 0.054810014,
#  'Loss/regularization_loss': 0.15158631,
#  'Loss/total_loss': 0.31479505,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.096s
# I0724 19:27:10.105078 139858778781568 model_lib_v2.py:707] Step 1600 per-step time 0.096s
# INFO:tensorflow:{'Loss/classification_loss': 0.07433839,
#  'Loss/localization_loss': 0.038639735,
#  'Loss/regularization_loss': 0.1509993,
#  'Loss/total_loss': 0.2639774,
#  'learning_rate': 0.079970405}
# I0724 19:27:10.105389 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.07433839,
#  'Loss/localization_loss': 0.038639735,
#  'Loss/regularization_loss': 0.1509993,
#  'Loss/total_loss': 0.2639774,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.097s
# I0724 19:27:19.790973 139858778781568 model_lib_v2.py:707] Step 1700 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.15212217,
#  'Loss/localization_loss': 0.06376437,
#  'Loss/regularization_loss': 0.15033878,
#  'Loss/total_loss': 0.3662253,
#  'learning_rate': 0.07995972}
# I0724 19:27:19.791276 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.15212217,
#  'Loss/localization_loss': 0.06376437,
#  'Loss/regularization_loss': 0.15033878,
#  'Loss/total_loss': 0.3662253,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.099s
# I0724 19:27:29.643481 139858778781568 model_lib_v2.py:707] Step 1800 per-step time 0.099s
# INFO:tensorflow:{'Loss/classification_loss': 0.06317045,
#  'Loss/localization_loss': 0.025010638,
#  'Loss/regularization_loss': 0.14968008,
#  'Loss/total_loss': 0.23786116,
#  'learning_rate': 0.0799474}
# I0724 19:27:29.643785 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.06317045,
#  'Loss/localization_loss': 0.025010638,
#  'Loss/regularization_loss': 0.14968008,
#  'Loss/total_loss': 0.23786116,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.098s
# I0724 19:27:39.461764 139858778781568 model_lib_v2.py:707] Step 1900 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.069334224,
#  'Loss/localization_loss': 0.049841247,
#  'Loss/regularization_loss': 0.14908704,
#  'Loss/total_loss': 0.2682625,
#  'learning_rate': 0.07993342}
# I0724 19:27:39.462055 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.069334224,
#  'Loss/localization_loss': 0.049841247,
#  'Loss/regularization_loss': 0.14908704,
#  'Loss/total_loss': 0.2682625,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.098s
# I0724 19:27:49.235089 139858778781568 model_lib_v2.py:707] Step 2000 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.15241982,
#  'Loss/localization_loss': 0.11393063,
#  'Loss/regularization_loss': 0.14842172,
#  'Loss/total_loss': 0.41477215,
#  'learning_rate': 0.07991781}
# I0724 19:27:49.235394 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.15241982,
#  'Loss/localization_loss': 0.11393063,
#  'Loss/regularization_loss': 0.14842172,
#  'Loss/total_loss': 0.41477215,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.102s
# I0724 19:27:59.479999 139858778781568 model_lib_v2.py:707] Step 2100 per-step time 0.102s
# INFO:tensorflow:{'Loss/classification_loss': 0.07975414,
#  'Loss/localization_loss': 0.025368974,
#  'Loss/regularization_loss': 0.14771605,
#  'Loss/total_loss': 0.25283915,
#  'learning_rate': 0.07990056}
# I0724 19:27:59.480300 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.07975414,
#  'Loss/localization_loss': 0.025368974,
#  'Loss/regularization_loss': 0.14771605,
#  'Loss/total_loss': 0.25283915,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.098s
# I0724 19:28:09.233977 139858778781568 model_lib_v2.py:707] Step 2200 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.08468341,
#  'Loss/localization_loss': 0.033207107,
#  'Loss/regularization_loss': 0.14705604,
#  'Loss/total_loss': 0.26494658,
#  'learning_rate': 0.07988167}
# I0724 19:28:09.234284 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.08468341,
#  'Loss/localization_loss': 0.033207107,
#  'Loss/regularization_loss': 0.14705604,
#  'Loss/total_loss': 0.26494658,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.097s
# I0724 19:28:18.979780 139858778781568 model_lib_v2.py:707] Step 2300 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.10763217,
#  'Loss/localization_loss': 0.09218322,
#  'Loss/regularization_loss': 0.14634468,
#  'Loss/total_loss': 0.34616005,
#  'learning_rate': 0.07986114}
# I0724 19:28:18.980078 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.10763217,
#  'Loss/localization_loss': 0.09218322,
#  'Loss/regularization_loss': 0.14634468,
#  'Loss/total_loss': 0.34616005,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.098s
# I0724 19:28:28.800020 139858778781568 model_lib_v2.py:707] Step 2400 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.061326627,
#  'Loss/localization_loss': 0.017189125,
#  'Loss/regularization_loss': 0.1455966,
#  'Loss/total_loss': 0.22411235,
#  'learning_rate': 0.07983897}
# I0724 19:28:28.800344 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.061326627,
#  'Loss/localization_loss': 0.017189125,
#  'Loss/regularization_loss': 0.1455966,
#  'Loss/total_loss': 0.22411235,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.099s
# I0724 19:28:38.688662 139858778781568 model_lib_v2.py:707] Step 2500 per-step time 0.099s
# INFO:tensorflow:{'Loss/classification_loss': 0.0702829,
#  'Loss/localization_loss': 0.01668699,
#  'Loss/regularization_loss': 0.14495733,
#  'Loss/total_loss': 0.23192722,
#  'learning_rate': 0.079815164}
# I0724 19:28:38.688951 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.0702829,
#  'Loss/localization_loss': 0.01668699,
#  'Loss/regularization_loss': 0.14495733,
#  'Loss/total_loss': 0.23192722,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.098s
# I0724 19:28:48.439929 139858778781568 model_lib_v2.py:707] Step 2600 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.09137372,
#  'Loss/localization_loss': 0.05976188,
#  'Loss/regularization_loss': 0.14495301,
#  'Loss/total_loss': 0.2960886,
#  'learning_rate': 0.07978972}
# I0724 19:28:48.440239 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.09137372,
#  'Loss/localization_loss': 0.05976188,
#  'Loss/regularization_loss': 0.14495301,
#  'Loss/total_loss': 0.2960886,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.098s
# I0724 19:28:58.238768 139858778781568 model_lib_v2.py:707] Step 2700 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.10316227,
#  'Loss/localization_loss': 0.04180692,
#  'Loss/regularization_loss': 0.14439534,
#  'Loss/total_loss': 0.28936452,
#  'learning_rate': 0.07976264}
# I0724 19:28:58.239091 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.10316227,
#  'Loss/localization_loss': 0.04180692,
#  'Loss/regularization_loss': 0.14439534,
#  'Loss/total_loss': 0.28936452,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.097s
# I0724 19:29:07.972890 139858778781568 model_lib_v2.py:707] Step 2800 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.116447106,
#  'Loss/localization_loss': 0.026571304,
#  'Loss/regularization_loss': 0.1437037,
#  'Loss/total_loss': 0.28672212,
#  'learning_rate': 0.07973392}
# I0724 19:29:07.973211 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.116447106,
#  'Loss/localization_loss': 0.026571304,
#  'Loss/regularization_loss': 0.1437037,
#  'Loss/total_loss': 0.28672212,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.096s
# I0724 19:29:17.588693 139858778781568 model_lib_v2.py:707] Step 2900 per-step time 0.096s
# INFO:tensorflow:{'Loss/classification_loss': 0.051849153,
#  'Loss/localization_loss': 0.025484182,
#  'Loss/regularization_loss': 0.14297424,
#  'Loss/total_loss': 0.22030757,
#  'learning_rate': 0.07970358}
# I0724 19:29:17.589005 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.051849153,
#  'Loss/localization_loss': 0.025484182,
#  'Loss/regularization_loss': 0.14297424,
#  'Loss/total_loss': 0.22030757,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.096s
# I0724 19:29:27.196933 139858778781568 model_lib_v2.py:707] Step 3000 per-step time 0.096s
# INFO:tensorflow:{'Loss/classification_loss': 0.046301827,
#  'Loss/localization_loss': 0.031522557,
#  'Loss/regularization_loss': 0.14225793,
#  'Loss/total_loss': 0.22008231,
#  'learning_rate': 0.0796716}
# I0724 19:29:27.197236 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.046301827,
#  'Loss/localization_loss': 0.031522557,
#  'Loss/regularization_loss': 0.14225793,
#  'Loss/total_loss': 0.22008231,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.103s
# I0724 19:29:37.525914 139858778781568 model_lib_v2.py:707] Step 3100 per-step time 0.103s
# INFO:tensorflow:{'Loss/classification_loss': 0.054680113,
#  'Loss/localization_loss': 0.017763054,
#  'Loss/regularization_loss': 0.14157853,
#  'Loss/total_loss': 0.21402168,
#  'learning_rate': 0.07963799}
# I0724 19:29:37.526225 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.054680113,
#  'Loss/localization_loss': 0.017763054,
#  'Loss/regularization_loss': 0.14157853,
#  'Loss/total_loss': 0.21402168,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.097s
# I0724 19:29:47.198071 139858778781568 model_lib_v2.py:707] Step 3200 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.040757187,
#  'Loss/localization_loss': 0.026631791,
#  'Loss/regularization_loss': 0.14085527,
#  'Loss/total_loss': 0.20824425,
#  'learning_rate': 0.07960275}
# I0724 19:29:47.198390 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.040757187,
#  'Loss/localization_loss': 0.026631791,
#  'Loss/regularization_loss': 0.14085527,
#  'Loss/total_loss': 0.20824425,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.098s
# I0724 19:29:56.962053 139858778781568 model_lib_v2.py:707] Step 3300 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.03955731,
#  'Loss/localization_loss': 0.011941314,
#  'Loss/regularization_loss': 0.14013037,
#  'Loss/total_loss': 0.191629,
#  'learning_rate': 0.07956588}
# I0724 19:29:56.962359 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.03955731,
#  'Loss/localization_loss': 0.011941314,
#  'Loss/regularization_loss': 0.14013037,
#  'Loss/total_loss': 0.191629,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.097s
# I0724 19:30:06.616887 139858778781568 model_lib_v2.py:707] Step 3400 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.042412326,
#  'Loss/localization_loss': 0.013655505,
#  'Loss/regularization_loss': 0.13941602,
#  'Loss/total_loss': 0.19548386,
#  'learning_rate': 0.079527386}
# I0724 19:30:06.617187 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.042412326,
#  'Loss/localization_loss': 0.013655505,
#  'Loss/regularization_loss': 0.13941602,
#  'Loss/total_loss': 0.19548386,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.099s
# I0724 19:30:16.511257 139858778781568 model_lib_v2.py:707] Step 3500 per-step time 0.099s
# INFO:tensorflow:{'Loss/classification_loss': 0.2778268,
#  'Loss/localization_loss': 0.33346555,
#  'Loss/regularization_loss': 0.14373618,
#  'Loss/total_loss': 0.75502855,
#  'learning_rate': 0.07948727}
# I0724 19:30:16.511565 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.2778268,
#  'Loss/localization_loss': 0.33346555,
#  'Loss/regularization_loss': 0.14373618,
#  'Loss/total_loss': 0.75502855,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.097s
# I0724 19:30:26.224476 139858778781568 model_lib_v2.py:707] Step 3600 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.08282641,
#  'Loss/localization_loss': 0.025320595,
#  'Loss/regularization_loss': 0.1447735,
#  'Loss/total_loss': 0.2529205,
#  'learning_rate': 0.079445526}
# I0724 19:30:26.224784 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.08282641,
#  'Loss/localization_loss': 0.025320595,
#  'Loss/regularization_loss': 0.1447735,
#  'Loss/total_loss': 0.2529205,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.098s
# I0724 19:30:36.045762 139858778781568 model_lib_v2.py:707] Step 3700 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.1402034,
#  'Loss/localization_loss': 0.049930662,
#  'Loss/regularization_loss': 0.14471468,
#  'Loss/total_loss': 0.33484876,
#  'learning_rate': 0.07940216}
# I0724 19:30:36.046058 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.1402034,
#  'Loss/localization_loss': 0.049930662,
#  'Loss/regularization_loss': 0.14471468,
#  'Loss/total_loss': 0.33484876,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.098s
# I0724 19:30:45.849568 139858778781568 model_lib_v2.py:707] Step 3800 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.07945589,
#  'Loss/localization_loss': 0.04747854,
#  'Loss/regularization_loss': 0.14405854,
#  'Loss/total_loss': 0.270993,
#  'learning_rate': 0.079357184}
# I0724 19:30:45.849902 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.07945589,
#  'Loss/localization_loss': 0.04747854,
#  'Loss/regularization_loss': 0.14405854,
#  'Loss/total_loss': 0.270993,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.098s
# I0724 19:30:55.626231 139858778781568 model_lib_v2.py:707] Step 3900 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.048784155,
#  'Loss/localization_loss': 0.025600111,
#  'Loss/regularization_loss': 0.14332062,
#  'Loss/total_loss': 0.21770489,
#  'learning_rate': 0.07931058}
# I0724 19:30:55.626553 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.048784155,
#  'Loss/localization_loss': 0.025600111,
#  'Loss/regularization_loss': 0.14332062,
#  'Loss/total_loss': 0.21770489,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.098s
# I0724 19:31:05.406476 139858778781568 model_lib_v2.py:707] Step 4000 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.0958636,
#  'Loss/localization_loss': 0.05008889,
#  'Loss/regularization_loss': 0.14280012,
#  'Loss/total_loss': 0.28875262,
#  'learning_rate': 0.07926236}
# I0724 19:31:05.406798 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.0958636,
#  'Loss/localization_loss': 0.05008889,
#  'Loss/regularization_loss': 0.14280012,
#  'Loss/total_loss': 0.28875262,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.100s
# I0724 19:31:15.365312 139858778781568 model_lib_v2.py:707] Step 4100 per-step time 0.100s
# INFO:tensorflow:{'Loss/classification_loss': 0.064858824,
#  'Loss/localization_loss': 0.056478515,
#  'Loss/regularization_loss': 0.14209342,
#  'Loss/total_loss': 0.26343077,
#  'learning_rate': 0.07921253}
# I0724 19:31:15.365632 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.064858824,
#  'Loss/localization_loss': 0.056478515,
#  'Loss/regularization_loss': 0.14209342,
#  'Loss/total_loss': 0.26343077,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.098s
# I0724 19:31:25.186249 139858778781568 model_lib_v2.py:707] Step 4200 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.04810475,
#  'Loss/localization_loss': 0.013973549,
#  'Loss/regularization_loss': 0.14133586,
#  'Loss/total_loss': 0.20341416,
#  'learning_rate': 0.07916109}
# I0724 19:31:25.186577 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.04810475,
#  'Loss/localization_loss': 0.013973549,
#  'Loss/regularization_loss': 0.14133586,
#  'Loss/total_loss': 0.20341416,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.096s
# I0724 19:31:34.835035 139858778781568 model_lib_v2.py:707] Step 4300 per-step time 0.096s
# INFO:tensorflow:{'Loss/classification_loss': 0.10372542,
#  'Loss/localization_loss': 0.034268443,
#  'Loss/regularization_loss': 0.14059025,
#  'Loss/total_loss': 0.27858412,
#  'learning_rate': 0.07910804}
# I0724 19:31:34.835346 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.10372542,
#  'Loss/localization_loss': 0.034268443,
#  'Loss/regularization_loss': 0.14059025,
#  'Loss/total_loss': 0.27858412,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.097s
# I0724 19:31:44.568218 139858778781568 model_lib_v2.py:707] Step 4400 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.041433703,
#  'Loss/localization_loss': 0.018988904,
#  'Loss/regularization_loss': 0.13984421,
#  'Loss/total_loss': 0.20026681,
#  'learning_rate': 0.07905338}
# I0724 19:31:44.568585 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.041433703,
#  'Loss/localization_loss': 0.018988904,
#  'Loss/regularization_loss': 0.13984421,
#  'Loss/total_loss': 0.20026681,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.098s
# I0724 19:31:54.319990 139858778781568 model_lib_v2.py:707] Step 4500 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.059686888,
#  'Loss/localization_loss': 0.016459327,
#  'Loss/regularization_loss': 0.13908488,
#  'Loss/total_loss': 0.21523109,
#  'learning_rate': 0.07899711}
# I0724 19:31:54.320285 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.059686888,
#  'Loss/localization_loss': 0.016459327,
#  'Loss/regularization_loss': 0.13908488,
#  'Loss/total_loss': 0.21523109,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.097s
# I0724 19:32:03.987722 139858778781568 model_lib_v2.py:707] Step 4600 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.06994988,
#  'Loss/localization_loss': 0.022114698,
#  'Loss/regularization_loss': 0.13851558,
#  'Loss/total_loss': 0.23058015,
#  'learning_rate': 0.078939244}
# I0724 19:32:03.988023 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.06994988,
#  'Loss/localization_loss': 0.022114698,
#  'Loss/regularization_loss': 0.13851558,
#  'Loss/total_loss': 0.23058015,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.095s
# I0724 19:32:13.477869 139858778781568 model_lib_v2.py:707] Step 4700 per-step time 0.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.041138645,
#  'Loss/localization_loss': 0.0097137075,
#  'Loss/regularization_loss': 0.1377893,
#  'Loss/total_loss': 0.18864164,
#  'learning_rate': 0.07887978}
# I0724 19:32:13.478181 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.041138645,
#  'Loss/localization_loss': 0.0097137075,
#  'Loss/regularization_loss': 0.1377893,
#  'Loss/total_loss': 0.18864164,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.097s
# I0724 19:32:23.133912 139858778781568 model_lib_v2.py:707] Step 4800 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.04861141,
#  'Loss/localization_loss': 0.010409834,
#  'Loss/regularization_loss': 0.13702764,
#  'Loss/total_loss': 0.19604889,
#  'learning_rate': 0.07881871}
# I0724 19:32:23.134205 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.04861141,
#  'Loss/localization_loss': 0.010409834,
#  'Loss/regularization_loss': 0.13702764,
#  'Loss/total_loss': 0.19604889,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.095s
# I0724 19:32:32.674278 139858778781568 model_lib_v2.py:707] Step 4900 per-step time 0.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.13381757,
#  'Loss/localization_loss': 0.012485253,
#  'Loss/regularization_loss': 0.13627303,
#  'Loss/total_loss': 0.28257585,
#  'learning_rate': 0.07875605}
# I0724 19:32:32.674593 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.13381757,
#  'Loss/localization_loss': 0.012485253,
#  'Loss/regularization_loss': 0.13627303,
#  'Loss/total_loss': 0.28257585,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.097s
# I0724 19:32:42.397896 139858778781568 model_lib_v2.py:707] Step 5000 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.07332923,
#  'Loss/localization_loss': 0.026457159,
#  'Loss/regularization_loss': 0.13556959,
#  'Loss/total_loss': 0.23535597,
#  'learning_rate': 0.078691795}
# I0724 19:32:42.398205 139858778781568 model_lib_v2.py:708] {'Loss/classification_loss': 0.07332923,
#  'Loss/localization_loss': 0.026457159,
#  'Loss/regularization_loss': 0.13556959,
#  'Loss/total_loss': 0.23535597,
#  'learning_rate': 0.078691795}

# %%
# !kill 5765

# %% [markdown]
# ## Análisis de los resultados con TensorBoard

# %%
# %reload_ext tensorboard
# %tensorboard --logdir "/content/ssd_mobilenet"

# %% [markdown]
# ## Exportación de modelo
#
# Exportamos nuestro modelo para poder utilizarlo en cualquier otro momento.

# %%
output_directory = "/content/fine_tuned_model"

# !python /content/models/research/object_detection/exporter_main_v2.py \
--input_type image_tensor \
--pipeline_config_path {target_config} \
--trained_checkpoint_dir {model_dir} \
--output_directory {output_directory}
# Out:
# 2022-07-24 19:32:49.997708: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0724 19:32:50.126353 140297560971136 deprecation.py:615] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# 2022-07-24 19:33:04.717094: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f99000e7390>, because it is not built.
# W0724 19:33:07.549705 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f99000e7390>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f98922a8fd0>, because it is not built.
# W0724 19:33:07.801576 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f98922a8fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e62eb10>, because it is not built.
# W0724 19:33:07.801790 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e62eb10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987e1a4250>, because it is not built.
# W0724 19:33:07.801897 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987e1a4250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f987bf12710>, because it is not built.
# W0724 19:33:07.801992 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f987bf12710>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987beeeed0>, because it is not built.
# W0724 19:33:07.802080 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987beeeed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beee2d0>, because it is not built.
# W0724 19:33:07.802160 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beee2d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f987e34ca50>, because it is not built.
# W0724 19:33:07.802238 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f987e34ca50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987beee110>, because it is not built.
# W0724 19:33:07.802314 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987beee110>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bfa1ad0>, because it is not built.
# W0724 19:33:07.802409 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bfa1ad0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f987e1cbe10>, because it is not built.
# W0724 19:33:07.802491 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f987e1cbe10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf62910>, because it is not built.
# W0724 19:33:07.802623 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf62910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987e1a0e90>, because it is not built.
# W0724 19:33:07.802722 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987e1a0e90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f98922af290>, because it is not built.
# W0724 19:33:07.802800 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f98922af290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf4fed0>, because it is not built.
# W0724 19:33:07.802875 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf4fed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bfb0d50>, because it is not built.
# W0724 19:33:07.802949 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bfb0d50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf4f690>, because it is not built.
# W0724 19:33:07.803029 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf4f690>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e0b2d90>, because it is not built.
# W0724 19:33:07.803104 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e0b2d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bfc6350>, because it is not built.
# W0724 19:33:07.803178 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bfc6350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e09c910>, because it is not built.
# W0724 19:33:07.803251 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e09c910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf0bbd0>, because it is not built.
# W0724 19:33:07.803338 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf0bbd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f98922af2d0>, because it is not built.
# W0724 19:33:07.803420 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f98922af2d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf24c90>, because it is not built.
# W0724 19:33:07.803501 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf24c90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf19f90>, because it is not built.
# W0724 19:33:07.803577 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf19f90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf19790>, because it is not built.
# W0724 19:33:07.803651 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bf19790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf19c50>, because it is not built.
# W0724 19:33:07.803725 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf19c50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987e09c250>, because it is not built.
# W0724 19:33:07.803801 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987e09c250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf4f110>, because it is not built.
# W0724 19:33:07.803884 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf4f110>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987befa590>, because it is not built.
# W0724 19:33:07.803961 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987befa590>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf38b10>, because it is not built.
# W0724 19:33:07.804043 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bf38b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987be4b690>, because it is not built.
# W0724 19:33:07.804118 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987be4b690>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987be4bb10>, because it is not built.
# W0724 19:33:07.804193 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987be4bb10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beb6f90>, because it is not built.
# W0724 19:33:07.804269 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beb6f90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e17f9d0>, because it is not built.
# W0724 19:33:07.804352 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987e17f9d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beb6110>, because it is not built.
# W0724 19:33:07.804440 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beb6110>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987beb6210>, because it is not built.
# W0724 19:33:07.804517 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987beb6210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beb6750>, because it is not built.
# W0724 19:33:07.804595 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987beb6750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f98922af310>, because it is not built.
# W0724 19:33:07.804672 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f98922af310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bfa7c10>, because it is not built.
# W0724 19:33:07.804747 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bfa7c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bee8090>, because it is not built.
# W0724 19:33:07.804821 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bee8090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bee89d0>, because it is not built.
# W0724 19:33:07.804896 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bee89d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bee8890>, because it is not built.
# W0724 19:33:07.804970 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bee8890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bee8ed0>, because it is not built.
# W0724 19:33:07.805050 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bee8ed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bee8c50>, because it is not built.
# W0724 19:33:07.805127 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f987bee8c50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bee8e10>, because it is not built.
# W0724 19:33:07.809911 140297560971136 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f987bee8e10>, because it is not built.
# W0724 19:33:23.487056 140297560971136 save.py:265] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 104). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/fine_tuned_model/saved_model/assets
# I0724 19:33:28.597569 140297560971136 builder_impl.py:780] Assets written to: /content/fine_tuned_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/fine_tuned_model/pipeline.config
# I0724 19:33:29.126279 140297560971136 config_util.py:254] Writing pipeline config file to /content/fine_tuned_model/pipeline.config

# %% [markdown]
# ## Compresión del modelo
#
# Comprimimos el modelo y lo descargamos para tenerlo local.

# %%
# !zip -r /content/fine_tuned_model.zip /content/fine_tuned_model
# Out:
#   adding: content/fine_tuned_model/ (stored 0%)
#   adding: content/fine_tuned_model/checkpoint/ (stored 0%)
#   adding: content/fine_tuned_model/checkpoint/checkpoint (deflated 42%)
#   adding: content/fine_tuned_model/checkpoint/ckpt-0.index (deflated 80%)
#   adding: content/fine_tuned_model/checkpoint/ckpt-0.data-00000-of-00001 (deflated 8%)
#   adding: content/fine_tuned_model/pipeline.config (deflated 68%)
#   adding: content/fine_tuned_model/saved_model/ (stored 0%)
#   adding: content/fine_tuned_model/saved_model/variables/ (stored 0%)
#   adding: content/fine_tuned_model/saved_model/variables/variables.index (deflated 78%)
#   adding: content/fine_tuned_model/saved_model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/fine_tuned_model/saved_model/assets/ (stored 0%)
#   adding: content/fine_tuned_model/saved_model/saved_model.pb (deflated 92%)
